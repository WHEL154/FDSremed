# %%
import pandas as pd
import numpy as np
import re
from sklearn.impute import SimpleImputer

# %%
pd.read_csv('datadump_s5-000.csv')
# Out:
#            dateid platform gamemode     mapname     matchid  roundnumber  \
# 0        20170212       PC  HOSTAGE  CLUB_HOUSE  1522380841            1
# 1        20170212       PC  HOSTAGE  CLUB_HOUSE  1522380841            4
# 2        20170212       PC  HOSTAGE  CLUB_HOUSE  1522380841            3
# 3        20170212       PC  HOSTAGE  CLUB_HOUSE  1522380841            4
# 4        20170212       PC  HOSTAGE  CLUB_HOUSE  1522380841            6
# ...           ...      ...      ...         ...         ...          ...
# 3999995  20170221      PS4  HOSTAGE        BANK  1368316041            6
# 3999996  20170221      PS4  HOSTAGE        BANK  1368316041            2
# 3999997  20170221      PS4  HOSTAGE        BANK  1368316041            1
# 3999998  20170221      PS4  HOSTAGE        BANK  1368316041            4
# 3999999  20170221      PS4  HOSTAGE        BANK  1368316041            8
#
#         objectivelocation   winrole          endroundreason  roundduration  \
# 0              STRIP_CLUB  Defender  AttackersKilledHostage            124
# 1                  CHURCH  Defender     AttackersEliminated            217
# 2                  CHURCH  Defender     AttackersEliminated            160
# 3                  CHURCH  Defender     AttackersEliminated            217
# 4                 BEDROOM  Attacker     DefendersEliminated            143
# ...                   ...       ...                     ...            ...
# 3999995        STAFF_ROOM  Defender     AttackersEliminated            158
# 3999996             VAULT  Attacker     DefendersEliminated            170
# 3999997             VAULT  Attacker     DefendersEliminated            142
# 3999998             VAULT  Defender     AttackersEliminated            156
# 3999999             VAULT  Defender     AttackersEliminated            141
#
#          ...  primarygrip primaryunderbarrel primarybarrel  secondaryweapon  \
# 0        ...     Vertical               None   Compensator          5.7_USG
# 1        ...     Vertical              Laser    Suppressor              P12
# 2        ...         None               None          None          MK1_9mm
# 3        ...         None               None   MuzzleBrake            PRB92
# 4        ...     Vertical              Laser    Suppressor              P12
# ...      ...          ...                ...           ...              ...
# 3999995  ...     Vertical               None          None        BEARING_9
# 3999996  ...     Vertical               None          None        BEARING_9
# 3999997  ...     Vertical               None   MuzzleBrake       M45_MEUSOC
# 3999998  ...     Vertical               None   Compensator               P9
# 3999999  ...        Angle               None          None              PMM
#
#          secondaryweapontype secondarysight  secondarygrip  \
# 0                    Pistols           None           None
# 1                    Pistols           None           None
# 2                    Pistols           None           None
# 3                    Pistols           None           None
# 4                    Pistols           None           None
# ...                      ...            ...            ...
# 3999995      Submachine_Guns         RedDot           None
# 3999996      Submachine_Guns         RedDot           None
# 3999997              Pistols           None           None
# 3999998              Pistols           None           None
# 3999999              Pistols           None           None
#
#          secondaryunderbarrel secondarybarrel    secondarygadget
# 0                        None            None     IMPACT_GRENADE
# 1                       Laser      Suppressor  DEPLOYABLE_SHIELD
# 2                        None            None  DEPLOYABLE_SHIELD
# 3                        None            None     IMPACT_GRENADE
# 4                       Laser      Suppressor  DEPLOYABLE_SHIELD
# ...                       ...             ...                ...
# 3999995                  None            None           CLAYMORE
# 3999996                  None            None           CLAYMORE
# 3999997                 Laser      Suppressor      SMOKE_GRENADE
# 3999998                  None            None      BREACH_CHARGE
# 3999999                  None            None         NITRO_CELL
#
# [4000000 rows x 31 columns]

# %%
df = pd.read_csv('datadump_s5-000.csv')
df = df.drop(['endroundreason','dateid','roundduration','clearancelevel','skillrank','role','team','haswon','nbkills','isdead','primaryweapon','primaryweapontype','primarysight','primarygrip','primaryunderbarrel','primarybarrel','secondaryweapon','secondaryweapontype','secondarysight','secondarygrip','secondaryunderbarrel','secondarybarrel','secondarygadget','platform','matchid'], axis=1, errors='ignore')
df.head()
# Out:
#   gamemode     mapname  roundnumber objectivelocation   winrole      operator
# 0  HOSTAGE  CLUB_HOUSE            1        STRIP_CLUB  Defender   SWAT-CASTLE
# 1  HOSTAGE  CLUB_HOUSE            4            CHURCH  Defender    GSG9-JAGER
# 2  HOSTAGE  CLUB_HOUSE            3            CHURCH  Defender    JTF2-FROST
# 3  HOSTAGE  CLUB_HOUSE            4            CHURCH  Defender  BOPE-CAVEIRA
# 4  HOSTAGE  CLUB_HOUSE            6           BEDROOM  Attacker    GSG9-JAGER

# %%
df['mapname'].unique()
# Out:
# array(['CLUB_HOUSE', 'PLANE', 'KANAL', 'HEREFORD_BASE', 'CONSULATE',
#        'YACHT', 'OREGON', 'BORDER', 'SKYSCRAPER', 'BANK', 'COASTLINE',
#        'BARTLETT_U.', 'HOUSE', 'KAFE_DOSTOYEVSKY', 'FAVELAS', 'CHALET'],
#       dtype=object)

# %%
df.tail()
# Out:
#         gamemode mapname  roundnumber objectivelocation   winrole  \
# 3999995  HOSTAGE    BANK            6        STAFF_ROOM  Defender
# 3999996  HOSTAGE    BANK            2             VAULT  Attacker
# 3999997  HOSTAGE    BANK            1             VAULT  Attacker
# 3999998  HOSTAGE    BANK            4             VAULT  Defender
# 3999999  HOSTAGE    BANK            8             VAULT  Defender
#
#                 operator
# 3999995       SAT-HIBANA
# 3999996       SAT-HIBANA
# 3999997         SWAT-ASH
# 3999998      GIGN-TWITCH
# 3999999  SPETSNAZ-KAPKAN

# %%
df.notnull()
# Out:
#          dateid  platform  gamemode  mapname  matchid  roundnumber  \
# 0          True      True      True     True     True         True
# 1          True      True      True     True     True         True
# 2          True      True      True     True     True         True
# 3          True      True      True     True     True         True
# 4          True      True      True     True     True         True
# ...         ...       ...       ...      ...      ...          ...
# 3999995    True      True      True     True     True         True
# 3999996    True      True      True     True     True         True
# 3999997    True      True      True     True     True         True
# 3999998    True      True      True     True     True         True
# 3999999    True      True      True     True     True         True
#
#          objectivelocation  winrole  endroundreason
# 0                     True     True            True
# 1                     True     True            True
# 2                     True     True            True
# 3                     True     True            True
# 4                     True     True            True
# ...                    ...      ...             ...
# 3999995               True     True            True
# 3999996               True     True            True
# 3999997               True     True            True
# 3999998               True     True            True
# 3999999               True     True            True
#
# [4000000 rows x 9 columns]
